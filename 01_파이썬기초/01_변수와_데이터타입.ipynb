# %% [markdown]
# # 01. 변수와 데이터타입
#
# ## 학습 목표
# - 변수의 개념을 이해하고 데이터를 저장할 수 있다
# - 숫자형, 문자열, 불리언 등 기본 데이터타입을 구분하고 활용할 수 있다
# - 타입 변환을 통해 데이터를 원하는 형태로 바꿀 수 있다
#
# ---
#
# ## 왜 배워야 하나요?
#
# 데이터분석에서 가장 먼저 하는 일은 **데이터를 변수에 담는 것**입니다.
# 매출액, 고객수, 상품명 등 모든 데이터는 변수에 저장되어야 분석할 수 있습니다.
# 데이터타입을 제대로 이해하지 못하면, 숫자인 줄 알았던 데이터가 문자열이라 계산이 안 되는 등의 문제가 자주 발생합니다.
# 실무에서 데이터 전처리 시간의 상당 부분이 이런 타입 문제를 해결하는 데 쓰입니다.

# %% [markdown]
# ---
# ## 1. 변수 (Variable)
#
# 변수는 **데이터를 담는 이름표**입니다.
# `=` 기호를 사용해 값을 저장합니다.
#
# ### 변수 이름 규칙
# - 영문, 숫자, 밑줄(`_`) 사용 가능
# - 숫자로 시작할 수 없음
# - 예약어(if, for, class 등) 사용 불가
# - **실무 관례**: 의미를 알 수 있는 이름 + snake_case 사용 (예: `total_revenue`, `customer_count`)

# %%
# 실무 예시: 월별 매출 데이터 저장

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 값을 업데이트해야 할 때
#
# **상황**: 처음 저장한 값을 나중에 바꿔야 할 때 (예: 1월 매출 → 2월 매출로 업데이트)
# → 같은 변수에 새 값을 대입하면 기존 값이 덮어씌워집니다.

# %%
# 변수 값 변경 (재할당)

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 관련 지표를 한 번에 저장해야 할 때
#
# **상황**: 매출, 비용, 이익처럼 관련된 여러 지표를 동시에 다뤄야 할 때
# → 한 줄에 여러 변수를 동시 할당하면 코드가 간결해집니다.

# %%
# 여러 변수 동시 할당 - 여러 지표를 한 번에 저장할 때 유용

# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 2. 숫자형 (Numeric Types)
#
# ### 정수형 (int)
# 소수점이 없는 숫자. 고객 수, 주문 건수, 재고 수량 등에 사용합니다.
#
# ### 실수형 (float)
# 소수점이 있는 숫자. 매출액, 비율, 평균값 등에 사용합니다.
#
# > **실무 팁**: 데이터분석에서 대부분의 숫자 연산 결과는 float으로 나옵니다.
# > Pandas에서 데이터를 불러올 때 결측치(NaN)가 있으면 정수 컬럼도 자동으로 float으로 변환됩니다.

# %%
# 정수형 (int)

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 매출 데이터로 핵심 지표를 계산해야 할 때
#
# **상황**: 매출 데이터가 있을 때 이익, 이익률, 건당 매출 등 파생 지표를 계산해야 할 때
# → 산술 연산자(+, -, *, /)를 활용해 각종 비즈니스 지표를 구합니다.

# %%
# 산술 연산 - 매출 분석 예시

# 아래에 코드를 작성하세요

# %% [markdown]
# ### Python 산술 연산자 정리
#
# **상황**: Python에서 사용 가능한 산술 연산자를 체계적으로 정리해야 할 때
# → 더하기, 빼기 외에도 몫(//)·나머지(%)·거듭제곱(**) 연산자를 알아둬야 데이터 가공이 편합니다.

# %%
# 주요 산술 연산자 정리

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 값을 계속 누적해야 할 때
#
# **상황**: 분기 매출처럼 값을 반복적으로 누적 합산해야 할 때
# → 복합 대입 연산자(+=)를 사용하면 누적 계산을 간결하게 작성할 수 있습니다.

# %%
# 복합 대입 연산자 - 누적 계산할 때 자주 사용

# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 3. 문자열 (String)
#
# 텍스트 데이터를 다루는 타입입니다.
# 고객 이름, 상품명, 주소, 리뷰 텍스트 등 데이터분석에서 문자열은 매우 자주 등장합니다.
#
# > **실무 팁**: 실무 데이터에서 숫자가 문자열로 저장되어 있는 경우가 매우 흔합니다.
# > 예: 전화번호 `"010-1234-5678"`, 우편번호 `"06134"`, 금액 `"1,500,000"` 등

# %%
# 문자열 생성

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 데이터 전처리: 문자열 정리가 필요할 때
#
# **상황**: 수집한 데이터에 불필요한 공백, 대소문자 혼재, 잘못된 표기가 섞여 있을 때
# → strip(), lower(), replace() 등 문자열 메서드로 데이터를 정제합니다.

# %%
# 문자열 주요 메서드 - 데이터 전처리에서 자주 사용

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 하나의 문자열을 쪼개서 정보를 추출해야 할 때
#
# **상황**: 로그 데이터나 구분자로 연결된 문자열에서 개별 정보를 분리해야 할 때
# → split()으로 문자열을 쪼개면 각 부분을 리스트로 받아 개별 접근할 수 있습니다.

# %%
# split() - 문자열을 쪼개기 (로그 데이터 파싱 등에 필수)

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 데이터를 보기 좋은 형태로 출력해야 할 때
#
# **상황**: 보고서나 로그에 변수 값을 포함한 문장을 출력해야 할 때 (천단위 콤마, 퍼센트 등)
# → f-string을 사용하면 변수를 문자열 안에 직접 넣고, 포맷 지정도 가능합니다.

# %%
# f-string (포맷 문자열) - 보고서 출력, 로그 작성 시 필수

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문자열의 특정 부분만 잘라내야 할 때
#
# **상황**: 상품 코드처럼 정해진 규칙으로 구성된 문자열에서 카테고리, 연도 등을 추출해야 할 때
# → 인덱싱과 슬라이싱으로 문자열의 원하는 위치의 값을 꺼낼 수 있습니다.

# %%
# 문자열 인덱싱과 슬라이싱

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 텍스트에서 특정 단어가 있는지 찾아야 할 때
#
# **상황**: 리뷰 데이터에서 특정 키워드 포함 여부를 확인하거나, 키워드 위치를 찾아야 할 때
# → `in` 연산자와 `find()` 메서드로 문자열 내 키워드를 검색합니다.

# %%
# 문자열 검색

# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 4. 불리언 (Boolean)
#
# `True` 또는 `False` 두 가지 값만 가지는 타입입니다.
# 데이터 필터링, 조건 분기, 결측치 판별 등에서 핵심적으로 사용됩니다.
#
# > **실무 팁**: Pandas에서 조건에 맞는 데이터만 필터링할 때 불리언 마스킹을 사용합니다.
# > 예: `df[df['age'] > 30]` → 내부적으로 True/False 배열로 필터링

# %%
# 불리언 기본

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 조건을 비교해서 판별해야 할 때
#
# **상황**: 점수가 기준 이상인지, 목표치와 같은지 등 다양한 조건을 비교해야 할 때
# → 비교 연산자(>, >=, <, <=, ==, !=)로 조건을 판별하면 True/False가 반환됩니다.

# %%
# 비교 연산자 정리

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 여러 조건을 동시에 만족하는지 판별해야 할 때
#
# **상황**: VIP 조건(회원 + 구매금액), 프로모션 대상(20대 또는 고액 구매) 등 복합 조건을 조합해야 할 때
# → and, or, not 논리 연산자로 여러 조건을 결합하여 판별합니다.

# %%
# 논리 연산자 - 여러 조건 조합 (데이터 필터링의 기본)

# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 5. 타입 변환 (Type Conversion)
#
# 실무 데이터는 타입이 뒤섞여 들어옵니다.
# CSV 파일에서 읽어온 숫자가 문자열인 경우, 금액에 콤마가 포함된 경우 등
# 분석 전에 올바른 타입으로 변환하는 작업이 반드시 필요합니다.
#
# > **실무 팁**: 데이터 전처리에서 가장 흔한 에러 중 하나가 타입 에러입니다.
# > `"1000" + "2000"` 의 결과는 `"10002000"` (문자열 연결)이지, `3000`이 아닙니다!

# %%
# 타입 확인 - type() 함수

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문자열로 된 숫자를 실제 숫자로 바꿔야 할 때
#
# **상황**: CSV에서 읽어온 매출 데이터가 "15,000,000" 같은 문자열이라 계산이 안 될 때
# → 콤마를 제거한 뒤 int() 또는 float()로 변환하면 숫자 연산이 가능해집니다.

# %%
# 문자열 → 숫자 변환

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 숫자를 문자열과 합쳐서 출력해야 할 때
#
# **상황**: 보고서 문장에 숫자 데이터를 포함시키거나, float를 int로 반올림해야 할 때
# → str()로 문자열 변환, int()로 소수점 버림, round()로 반올림을 수행합니다.

# %%
# 숫자 → 문자열 변환 (보고서 출력 시)

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 어떤 값이 참/거짓으로 판별되는지 알아야 할 때
#
# **상황**: 조건문에서 0, 빈 문자열, None 등이 어떻게 처리되는지 알아야 할 때
# → bool() 변환 규칙을 알면 if문에서 데이터 유무를 간결하게 판별할 수 있습니다.

# %%
# 불리언 변환 - 어떤 값이 True/False로 변환되는지 알아두면 유용

# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 6. None 타입
#
# `None`은 **값이 없음**을 나타냅니다.
# 데이터분석에서 결측치(missing value)의 개념과 직접 연결됩니다.
#
# > **실무 팁**: Pandas에서는 `None`이 `NaN`(Not a Number)으로 변환됩니다.
# > 결측치 처리는 데이터분석의 가장 기본적이면서 중요한 전처리 과정입니다.

# %%
# None 사용 예시

# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 실습 문제
#
# 아래 문제를 직접 코드로 작성해보세요.

# %% [markdown]
# ### 문제 1. 매출 지표 계산
#
# 한 쇼핑몰의 1월 데이터가 다음과 같습니다:
# - 총 매출: 85,000,000원
# - 총 비용: 52,000,000원
# - 총 주문 건수: 2,340건
# - 총 방문자 수: 45,000명
#
# 다음을 계산하여 출력하세요:
# 1. 순이익
# 2. 이익률 (소수점 첫째자리까지, % 포함)
# 3. 건당 평균 매출 (소수점 없이)
# 4. 전환율 (주문 건수 / 방문자 수, 소수점 둘째자리까지 %로)

# %%
# 문제 1 풀이

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 2. 데이터 정제
#
# CSV 파일에서 읽어온 아래 데이터를 적절한 타입으로 변환하고, 고객 정보를 한 줄로 출력하세요.
#
# ```
# name = "  박지민  "
# age = "29"
# purchase_amount = "1,250,000"
# is_vip = "True"
# ```
#
# 출력 예시: `고객: 박지민 | 나이: 29세 | 구매액: 1,250,000원 | VIP: True`

# %%
# 문제 2 풀이

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 3. 상품 코드 파싱
#
# 상품 코드가 `"FOOD-2024-A-00312"` 형태로 되어 있습니다.
# - 카테고리: 처음 4글자 (FOOD)
# - 연도: 5~8번째 글자 (2024)
# - 등급: 10번째 글자 (A)
# - 일련번호: 12번째 이후 (00312)
#
# 각각을 변수에 저장하고, 연도는 정수로 변환하여 출력하세요.

# %%
# 문제 3 풀이

# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 4. 고객 등급 판별
#
# 다음 변수들을 사용해서, 아래 조건이 True인지 False인지 각각 출력하세요.
#
# ```python
# age = 35
# monthly_spend = 280000
# is_member = True
# membership_months = 14
# ```
#
# 1. 프리미엄 대상: 회원이면서 월 소비 25만원 이상
# 2. 장기 고객: 가입 기간 12개월 초과
# 3. 타겟 마케팅 대상: (30대이면서 회원) 또는 (월 소비 30만원 이상)

# %%
# 문제 4 풀이

# 아래에 코드를 작성하세요
