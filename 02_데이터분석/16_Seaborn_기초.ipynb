# %% [markdown]
# # 16. Seaborn 기초
#
# ## 학습 목표
# - Seaborn의 장점을 이해하고 기본 스타일을 설정한다
# - `countplot`, `barplot`, `histplot`, `boxplot`을 사용할 수 있다
# - `heatmap`으로 상관관계를 시각화할 수 있다
#
# ---
#
# ## 왜 배워야 하나요?
#
# Matplotlib만으로도 대부분의 차트를 그릴 수 있지만, **DataFrame과 궁합이 더 좋은 Seaborn**을 쓰면:
# - 컬럼명만 전달하면 차트가 자동으로 완성됨
# - 기본 색감이 훨씬 예쁨
# - 상관관계 히트맵 같은 고급 차트가 한 줄로 그려짐
#
# 실무 EDA 단계에서 **가장 빠르게 인사이트를 뽑을 수 있는** 라이브러리입니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 1. `countplot` - 카테고리 빈도

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 2. `barplot` - 평균값 막대

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 3. `histplot` - 히스토그램

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 4. `boxplot` - 분포 비교

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 5. `heatmap` - 상관관계 히트맵
#
# **수치형 변수들의 상관관계**를 한눈에 보여줍니다. EDA의 꽃입니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 실습문제
#
# ### 문제 1. 성별 countplot
#
# `customers.csv`에서 성별 고객 수를 `sns.countplot`으로 그리세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 2. 카테고리별 평균 단가 barplot
#
# `products.csv`에서 카테고리별 **평균 단가**를 `barplot`으로 그리세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 3. 등급별 연령 분포 boxplot
#
# `customers.csv`에서 회원등급별 연령 분포를 `boxplot`으로 그리세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 4. 상관관계 히트맵
#
# `orders + products + customers`를 병합 후, `수량`, `단가`, `매출`, `연령`의 상관관계 히트맵을 그리세요.

# %%
# 아래에 코드를 작성하세요
