# %% [markdown]
# # 08. 데이터 병합 (merge / concat)
#
# ## 학습 목표
# - `concat`으로 여러 DataFrame을 이어붙일 수 있다
# - `merge`로 여러 테이블을 키 컬럼 기준으로 조인할 수 있다
# - `inner`, `left`, `right`, `outer` 조인의 차이를 이해한다
#
# ---
#
# ## 왜 배워야 하나요?
#
# 실무 데이터는 **하나의 테이블에 모든 정보가 있지 않습니다.**
# - 주문 테이블에는 `상품코드`만 있고, 상품명/카테고리는 **상품 테이블**에 있음
# - 고객ID만 있고, 고객 이름/지역은 **고객 테이블**에 있음
#
# 이런 테이블들을 **공통 키 컬럼**으로 합쳐야 제대로 된 분석이 가능합니다.
# SQL의 `JOIN`과 같은 개념입니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 1. `concat` - 세로/가로로 이어붙이기
#
# **같은 구조의 데이터**를 쌓는 용도입니다. 분기별 파일 합치기 등.

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 2. `merge` - 키 컬럼으로 조인
#
# **서로 다른 구조의 테이블**을 공통 키로 연결할 때 사용합니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 2-1. 조인 타입 (`how` 옵션)
#
# | 옵션 | 설명 |
# |------|------|
# | `inner` (기본) | 양쪽 모두에 있는 키만 |
# | `left` | 왼쪽(기준) 테이블 전부 + 오른쪽 매칭 |
# | `right` | 오른쪽 테이블 전부 + 왼쪽 매칭 |
# | `outer` | 양쪽 모두 (매칭 없으면 NaN) |

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 3. 키 컬럼 이름이 다를 때
#
# ```python
# # left_on / right_on 사용
# # 예: orders의 "cust_id"와 customers의 "고객ID"를 조인
# # result = orders.merge(customers, left_on="cust_id", right_on="고객ID")
# ```

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 4. 매칭 확인 (`indicator`)
#
# 조인이 제대로 되었는지 확인하는 디버깅 옵션입니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 실습문제
#
# ### 문제 1. 주문에 상품 정보 붙이기
#
# `orders_q1.csv`와 `products.csv`를 `상품코드` 기준으로 inner join하여
# `주문번호`, `주문일자`, `상품명`, `카테고리`, `수량`, `단가` 컬럼만 남기세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 2. 전체 분기 주문 합치고 매출 계산
#
# 1. `orders_q1.csv` ~ `orders_q4.csv`를 `concat`으로 합치세요.
# 2. `products.csv`와 `merge`하세요.
# 3. `매출` 컬럼(수량 × 단가)을 추가하세요.
# 4. 전체 총매출을 출력하세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 3. 주문 + 상품 + 고객 3-way 조인
#
# `orders_q1.csv`, `products.csv`, `customers.csv` 세 테이블을 모두 합쳐서
# `주문번호`, `고객명`, `지역`, `회원등급`, `상품명`, `단가`, `수량` 컬럼을 남기세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 4. 매칭 확인
#
# `orders_q1.csv`와 `products.csv`를 `outer` 조인하고, `indicator=True`를 사용해
# 양쪽 모두/한쪽만에 있는 키의 개수를 출력하세요.

# %%
# 아래에 코드를 작성하세요
