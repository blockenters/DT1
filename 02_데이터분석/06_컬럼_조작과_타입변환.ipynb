# %% [markdown]
# # 06. 컬럼 조작과 타입 변환
#
# ## 학습 목표
# - 컬럼을 추가/삭제/이름 변경할 수 있다
# - 값을 `replace`, `map`으로 치환할 수 있다
# - `astype`, `to_numeric`, `to_datetime`으로 타입을 변환할 수 있다
# - `apply`로 사용자 정의 함수를 적용할 수 있다
#
# ---
#
# ## 왜 배워야 하나요?
#
# 원본 데이터를 그대로 분석에 쓰는 경우는 드뭅니다. 대부분은:
# - **파생 컬럼**(예: 단가 × 수량 = 매출)을 만들고,
# - **잘못된 타입**(예: 숫자가 문자열로 들어옴)을 고치고,
# - **값을 정리**(예: "남" → "M")하는 과정을 거칩니다.
#
# 이 과정이 바로 **데이터 가공**이며, 분석의 퀄리티를 좌우합니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 1. 컬럼 추가
#
# **가장 자주 하는 작업**: 기존 컬럼으로 새 컬럼 만들기 (파생 컬럼)

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 2. 컬럼 삭제 - `drop`

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 3. 컬럼명 변경 - `rename`

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 4. 값 치환 - `replace`, `map`

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 5. 타입 변환
#
# > **자주 겪는 문제**: CSV에서 읽은 숫자 컬럼이 `object`(문자열)로 들어오는 경우.
# > 집계/정렬이 엉망이 되므로 **분석 전에 반드시 타입 확인**해야 합니다.

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 6. `apply` - 사용자 정의 함수 적용
#
# 복잡한 변환 로직은 함수로 만들어 `apply`로 적용합니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 실습문제
#
# ### 문제 1. 상품 파생 컬럼 만들기
#
# `products.csv`를 읽어 다음을 추가하세요.
# 1. `VAT포함가` 컬럼 (단가 × 1.1)
# 2. `할인가` 컬럼 (단가 × 0.8, 20% 할인)
# 3. `가격대` 컬럼: 단가 100만원 이상 `"프리미엄"`, 10만원 이상 `"중가"`, 그 외 `"저가"`

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 2. 컬럼명 영문 변경
#
# `customers.csv`의 컬럼명을 아래와 같이 영문으로 바꾸세요.
#
# | 원본 | 변경 |
# |------|------|
# | 고객ID | customer_id |
# | 고객명 | name |
# | 성별 | gender |
# | 연령 | age |
# | 지역 | region |
# | 가입일 | join_date |
# | 회원등급 | grade |

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 3. 타입 변환
#
# `customers.csv`를 읽어 `가입일` 컬럼을 `datetime`으로 변환하고,
# 가입 연도(`가입연도`) 컬럼을 새로 추가하세요.
#
# > 힌트: `pd.to_datetime()` 후 `.dt.year` 사용

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 4. map/apply로 카테고리 변환
#
# `customers.csv`에서:
# 1. `회원등급`을 `{VIP: 3, 실버: 2, 일반: 1}`로 매핑한 `등급점수` 컬럼을 만드세요.
# 2. `연령`을 10세 단위로 나눠 `연령대`(예: 30 → "30대") 컬럼을 만드세요.
# 3. 결과 일부를 출력하세요.

# %%
# 아래에 코드를 작성하세요
