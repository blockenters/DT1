# %% [markdown]
# # 07. 정렬과 요약 통계
#
# ## 학습 목표
# - `sort_values`, `sort_index`로 데이터를 정렬할 수 있다
# - `describe`, `mean/median/std` 등 요약 통계를 구할 수 있다
# - `value_counts`, `unique`, `nunique`로 카테고리를 분석할 수 있다
# - `nlargest`, `nsmallest`로 상위/하위 N개를 빠르게 추출할 수 있다
#
# ---
#
# ## 왜 배워야 하나요?
#
# 데이터의 **전체 분포**를 파악하고, **Top N**을 뽑는 작업은 분석의 기본입니다.
# 예: "매출 상위 10개 상품", "나이 평균", "지역별 고객 수" — 모두 이 단원의 내용입니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 1. 정렬 - `sort_values`

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 2. 요약 통계

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 3. 카테고리 분석 - `value_counts`, `unique`, `nunique`

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 4. 상위/하위 N개 - `nlargest`, `nsmallest`
#
# 정렬 + head()와 같은 효과지만 더 빠르고 간결합니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 5. 여러 컬럼 한번에 통계

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 실습문제
#
# ### 문제 1. 고객 정렬
#
# `customers.csv`에서:
# 1. 연령이 많은 순으로 상위 5명을 출력하세요.
# 2. 지역 오름차순 + 연령 내림차순으로 정렬한 결과 상위 10명을 출력하세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 2. 상품 단가 분석
#
# `products.csv`를 사용해:
# 1. 단가의 평균, 중앙값, 표준편차를 출력하세요.
# 2. 단가가 가장 높은 상품 3개와 가장 낮은 상품 3개를 각각 출력하세요.
# 3. 카테고리 종류와 개수를 출력하세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 3. 회원등급 분포
#
# `customers.csv`에서:
# 1. `회원등급`별 고객 수를 `value_counts()`로 구하세요.
# 2. 각 등급의 비율(%)을 구하세요.
# 3. `지역`의 종류와 개수를 출력하세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 4. 상위 지역 찾기
#
# `customers.csv`에서 고객 수가 가장 많은 지역 3개를 `value_counts()`와 `head()`를 이용해 찾으세요.

# %%
# 아래에 코드를 작성하세요
