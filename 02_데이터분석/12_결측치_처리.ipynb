# %% [markdown]
# # 12. 결측치 처리
#
# ## 학습 목표
# - 결측치(NaN)를 탐지하고 개수를 파악할 수 있다
# - `dropna`로 결측치를 제거할 수 있다
# - `fillna`로 결측치를 채울 수 있다 (고정값, 평균, ffill/bfill)
# - 상황에 맞는 결측치 처리 전략을 선택할 수 있다
#
# ---
#
# ## 왜 배워야 하나요?
#
# 실무 데이터에는 **반드시 결측치가 있습니다.** 고객이 이메일을 입력 안 했거나,
# 센서가 작동 안 했거나, 시스템 오류로 값이 빠졌거나... 이유는 다양합니다.
#
# 결측치를 제대로 처리하지 않으면:
# - 평균/합계 같은 집계가 틀어지고
# - 머신러닝 모델이 에러를 내고
# - 시각화가 깨집니다
#
# > **중요**: "무조건 평균으로 채우기" 같은 일괄 처리는 위험합니다. **데이터 맥락**에 맞게 판단해야 합니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 1. 결측치 탐지

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 2. 결측치 제거 - `dropna`

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 3. 결측치 채우기 - `fillna`

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 4. `ffill` / `bfill` - 이전/다음 값으로 채우기
#
# 시계열 데이터에 유용합니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 5. 실무 패턴: 여러 컬럼 한번에 처리
#
# ```python
# # 숫자형은 중앙값, 카테고리형은 최빈값으로 채우기 (일반적 패턴)
# for col in df.select_dtypes(include="number").columns:
#     df[col] = df[col].fillna(df[col].median())
#
# for col in df.select_dtypes(include="object").columns:
#     df[col] = df[col].fillna(df[col].mode()[0])
# ```

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 실습문제
#
# ### 문제 1. 결측치 파악
#
# `dirty_orders.csv`를 읽어:
# 1. 컬럼별 결측치 개수를 출력하세요.
# 2. 컬럼별 결측치 비율(%)을 출력하세요.
# 3. 결측치가 하나라도 있는 행의 수를 출력하세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 2. 핵심 컬럼 기준 제거
#
# `수량`과 `단가` 컬럼에 결측이 있는 행은 제거하고, 처리 전/후 행 수를 비교하세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 3. 결측치 채우기
#
# `dirty_orders.csv`에서:
# 1. `수량`의 결측치는 `0`으로 채우세요.
# 2. `단가`의 결측치는 해당 컬럼의 **중앙값**으로 채우세요.
# 3. 처리 후 결측 개수를 출력하세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 4. 타입별 일괄 채우기
#
# `dirty_orders.csv`에서:
# - 숫자형 컬럼은 **중앙값**
# - 문자열 컬럼은 **최빈값**
#
# 으로 모두 채우고, 처리 후 결측치 합계를 출력하세요.

# %%
# 아래에 코드를 작성하세요
