# %% [markdown]
# # 05. 데이터 선택과 필터링
#
# ## 학습 목표
# - 열 선택(단일/다중)을 할 수 있다
# - `loc`과 `iloc`의 차이를 이해하고 사용할 수 있다
# - 조건식(불리언 인덱싱)으로 행을 필터링할 수 있다
# - `isin`, `between`, `str.contains`로 다양한 조건을 표현할 수 있다
#
# ---
#
# ## 왜 배워야 하나요?
#
# 데이터분석에서 **가장 자주 하는 작업**이 바로 "원하는 행/열만 골라내기" 입니다.
# SQL의 `SELECT`, `WHERE` 절과 같은 역할이며, Pandas에서는 이를 **인덱싱/필터링** 이라고 합니다.
#
# > **실무 팁**: `df[조건식]` 패턴 하나로 데이터 필터링의 90%를 해결할 수 있습니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 1. 열 선택

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 2. `loc`과 `iloc` - 행 선택
#
# | 방법 | 기준 | 예시 |
# |------|------|------|
# | `loc` | 라벨(이름) 기반 | `df.loc[0, "고객명"]` |
# | `iloc` | 위치(숫자) 기반 | `df.iloc[0, 1]` |
#
# 둘 다 `df.loc[행, 열]` 형태로 행과 열을 동시에 지정할 수 있습니다.

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 3. 조건 필터링 (불리언 인덱싱)
#
# **가장 중요한 패턴!** `df[조건식]` 으로 조건에 맞는 행만 추출합니다.

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 4. `isin`, `between`, `str.contains`
#
# 여러 값 중 하나, 범위, 문자열 포함 여부를 표현할 때 유용합니다.

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 5. 행과 열 동시에 필터링
#
# 조건 필터링 + 열 선택을 한번에 하는 패턴입니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 실습문제
#
# > 먼저 데이터를 불러오세요.
# >
# > ```python
# > customers = pd.read_csv("../data/customers.csv")
# > products = pd.read_csv("../data/products.csv")
# > ```
#
# ### 문제 1. 고객 필터링
# 1. 여성(`성별 == "여"`) 고객만 추출하세요.
# 2. 연령이 30~39세인 고객만 추출하고 행 수를 출력하세요.
# 3. 서울 또는 경기 지역의 VIP 고객만 추출하세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 2. 상품 필터링
# 1. 단가가 10만원 이상인 상품을 추출하세요.
# 2. `카테고리`가 `컴퓨터` 또는 `주변기기`인 상품만 추출하세요.
# 3. 상품명에 `키보드` 또는 `마우스`가 포함된 상품만 추출하세요 (`|` 또는 `str.contains` 활용).

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 3. loc로 행+열 선택
#
# `customers`에서 `회원등급`이 `VIP`인 고객의 `고객명`, `연령`, `지역` 컬럼만 골라
# 상위 5명을 출력하세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 4. 종합 필터링
#
# `customers`에서 아래 조건을 모두 만족하는 고객 수를 출력하세요.
# - 서울 거주
# - 연령 20대 또는 30대
# - VIP 또는 실버 등급

# %%
# 아래에 코드를 작성하세요
