# %% [markdown]
# # 04. Pandas - 파일 입출력 (CSV/Excel)
#
# ## 학습 목표
# - `read_csv`로 CSV 파일을 읽을 수 있다
# - 인코딩, 구분자, 인덱스 등 주요 옵션을 사용할 수 있다
# - `to_csv`로 분석 결과를 파일로 저장할 수 있다
# - 여러 CSV 파일을 반복문으로 한 번에 읽어올 수 있다
#
# ---
#
# ## 왜 배워야 하나요?
#
# 실무 데이터는 대부분 **CSV, Excel, DB**에서 가져옵니다. 직접 딕셔너리로 데이터를 만드는 일은 거의 없습니다.
# 특히 **CSV 파일 읽기**는 데이터분석의 첫 단계이므로 **가장 자주 쓰는 기능**입니다.
#
# > **실무 팁**: 실제 파일은 인코딩(한글), 구분자(쉼표/탭), 컬럼 타입 등에서 문제가 자주 발생합니다.
# > 옵션을 잘 알고 있어야 제대로 읽을 수 있습니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 1. CSV 파일 읽기 - `read_csv()`
#
# 가장 기본이 되는 사용법입니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 1-1. 주요 옵션
#
# | 옵션 | 설명 |
# |------|------|
# | `encoding` | 파일 인코딩. 한글 파일은 `utf-8`, `cp949`, `euc-kr` 등 |
# | `sep` | 구분자. 기본 `,` / 탭 구분은 `\t` |
# | `index_col` | 특정 컬럼을 인덱스로 지정 |
# | `parse_dates` | 날짜 컬럼을 자동으로 datetime으로 변환 |
# | `usecols` | 필요한 컬럼만 읽기 (큰 파일에 유용) |
# | `nrows` | 처음 N행만 읽기 (미리보기용) |

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 2. CSV 파일 쓰기 - `to_csv()`
#
# 분석 결과, 집계 결과, 전처리 결과를 파일로 저장합니다.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 3. 여러 CSV 파일 한번에 읽기 (실무 핵심 패턴)
#
# 월별/분기별로 분리된 파일들을 한번에 합치는 패턴입니다.
#
# > **실무 시나리오**: `orders_q1.csv`, `orders_q2.csv` 처럼 분기별로 나뉜 주문 데이터를
# > 한 개의 DataFrame으로 합쳐서 연간 분석을 수행합니다.

# %%
# 아래에 코드를 작성하세요

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ---
# ## 4. Excel 파일 입출력 (간단히)
#
# ```python
# # Excel 읽기: pd.read_excel("파일명.xlsx", sheet_name="시트명")
# # Excel 쓰기: df.to_excel("파일명.xlsx", index=False)
# ```
#
# > `openpyxl` 라이브러리가 필요합니다. 설치 후 사용합니다.

# %% [markdown]
# ---
# ## 실습문제
#
# ### 문제 1. 상품 데이터 읽기
#
# `../data/products.csv` 파일을 다양한 방식으로 읽어보세요.
#
# 1. 기본 방식으로 읽고 `shape`과 `head()`를 출력하세요.
# 2. `상품코드`를 인덱스로 지정해서 읽으세요.
# 3. 처음 2행만 미리보기로 읽으세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 2. 필요한 컬럼만 읽기
#
# `../data/customers.csv`에서 `고객ID`, `고객명`, `회원등급` 세 컬럼만 읽어서,
# `회원등급`이 `"VIP"`인 고객만 `/tmp/vip_list.csv`로 저장하세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 3. 여러 파일 합치기
#
# `../data/orders_q1.csv` ~ `orders_q4.csv`를 모두 읽어 하나의 DataFrame으로 합치고,
# 합친 결과의 전체 행 수와 주문일자의 최소/최대 값을 출력하세요.

# %%
# 아래에 코드를 작성하세요

# %% [markdown]
# ### 문제 4. 분기 컬럼을 추가해서 합치기
#
# 위 문제에서 합친 데이터에 파일명에서 추출한 `분기` 컬럼(q1/q2/q3/q4)을 추가하고,
# `분기`별 주문 건수를 출력하세요.

# %%
# 아래에 코드를 작성하세요
